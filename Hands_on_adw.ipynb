# %% [markdown]
# <a href="https://colab.research.google.com/github/sizakia/latihan-prakadw/blob/main/Hands_on_adw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= 1+1
x
# Out:
# 2
